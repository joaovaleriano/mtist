# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("mtist_datasets_food/dataset_3.csv")
df
# Out:
#      Unnamed: 0       time  species_0  species_1  species_2      food  \
# 0             0   0.000000   0.040000   0.050000   0.010000  1.000000
# 1             1   2.121212   0.903525   3.105965   0.027373  0.649396
# 2             2   4.242424   1.357422   1.042841   0.199043  0.271081
# 3             3   6.363636   1.414259   1.244671   0.612367  0.286444
# 4             4   8.484848   1.006725   0.576509   1.188336  0.440416
# ..          ...        ...        ...        ...        ...       ...
# 145         145  21.212121   1.140563   1.109548   1.019411  0.399305
# 146         146  23.333333   1.112642   0.738648   1.061348  0.205084
# 147         147  25.454545   1.076488   1.124332   0.992756  0.273086
# 148         148  27.575758   1.079466   0.922647   1.141587  0.358370
# 149         149  30.000000   1.256093   1.098931   0.946022  0.382977
#
#     ground_truth  timeseries_id  noise  n_species  did  n_timeseries  \
# ...

# %%
t = df["time"]
species = df[[i for i in df.columns if i.split("_")[0]=="species"]]
food = df["food"]

# %%
plt.plot(t[:15], species[:15])
plt.plot(t[:15], food[:15])
